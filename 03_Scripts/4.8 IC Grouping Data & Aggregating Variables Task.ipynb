# %% [markdown]
# # 4.8 IC Grouping Data & Aggregating Variables Task

# %% [markdown]
# ## Contents

# %% [markdown]
# ### 01. Importing Libraries

# %% [markdown]
# ### 02. Split Data into Groups and Aggregate

# %% [markdown]
# ### 03. Analyse Result

# %% [markdown]
# ### 04. Create a Loyalty Flag

# %% [markdown]
# ### 05. Check Statistics

# %% [markdown]
# ### 06. Create a Spending Flag

# %% [markdown]
# ### 07. Create a Frequency Flag

# %% [markdown]
# ### 08. Export Dataframe

# %% [markdown]
# #### 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing df_ords_prods_merge
path = r'/Users/yaseminmustafa/Desktop/CareerFoundry/Exercise 4/15-05-2025_Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,"02_Data/Prepared Data/ords_prods_merge_aggregated.pkl"))

# %%
# Check output
ords_prods_merge.head()
# Out:
#    order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0         2  202279.0         prior           3.0                 5.0
# 1         2  202279.0         prior           3.0                 5.0
# 2         2  202279.0         prior           3.0                 5.0
# 3         2  202279.0         prior           3.0                 5.0
# 4         2  202279.0         prior           3.0                 5.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                9.0                     8.0     33120.0                1.0
# 1                9.0                     8.0     28985.0                2.0
# 2                9.0                     8.0      9327.0                3.0
# 3                9.0                     8.0     45918.0                4.0
# 4                9.0                     8.0     30035.0                5.0
#
#    reordered  ...           product_name aisle_id  department_id  prices  \
# 0        1.0  ...     Organic Egg Whites       86             16    11.3
# 1        1.0  ...  Michigan Organic Kale       83              4    13.4
# 2        0.0  ...          Garlic Powder      104             13     3.6
# 3        1.0  ...         Coconut Butter       19             13     8.4
# 4        0.0  ...      Natural Sweetener       17             13    13.7
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy  Regularly busy        Average orders
# 2  Low-range product  Regularly busy  Regularly busy        Average orders
# 3  Mid-range product  Regularly busy  Regularly busy        Average orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders
#
#   max_order  loyalty_flag
# 0       8.0  New customer
# 1       8.0  New customer
# 2       8.0  New customer
# 3       8.0  New customer
# 4       8.0  New customer
#
# [5 rows x 21 columns]

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %% [markdown]
# #### 02. Split Data into Groups and Aggregate

# %%
# Split the data into groups based on department_id and apply agg()
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# #### 03. Analyse Result

# %% [markdown]
# ##### Most departments in the subset have slightly higher mean order_number values than in the full dataset. The subset likely captures more recent or sequential order activity, which may be skewing averages upwards, especially if users who order frequently are overrepresented early in the dataset.

# %% [markdown]
# #### 04. Create a Loyalty Flag

# %% [markdown]
# ##### The loyalty flag has already been created using the `transform()` and `loc()` functions in the previous steps and was included in the exported DataFrame. However, I have repeted the steps again.

# %%
# Split the data into groups based on the “user_id” column.
# Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# Create a new column, “max_order,” into which you’ll place the results of your aggregation.
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/nr/1brwh_xs1n5_2h6494zpg7jm0000gn/T/ipykernel_6708/1765782716.py:4: FutureWarning: The provided callable <function max at 0x10f90c900> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check output
ords_prods_merge.head()
# Out:
#    order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0         2  202279.0         prior           3.0                 5.0
# 1         2  202279.0         prior           3.0                 5.0
# 2         2  202279.0         prior           3.0                 5.0
# 3         2  202279.0         prior           3.0                 5.0
# 4         2  202279.0         prior           3.0                 5.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                9.0                     8.0     33120.0                1.0
# 1                9.0                     8.0     28985.0                2.0
# 2                9.0                     8.0      9327.0                3.0
# 3                9.0                     8.0     45918.0                4.0
# 4                9.0                     8.0     30035.0                5.0
#
#    reordered  ...           product_name aisle_id  department_id  prices  \
# 0        1.0  ...     Organic Egg Whites       86             16    11.3
# 1        1.0  ...  Michigan Organic Kale       83              4    13.4
# 2        0.0  ...          Garlic Powder      104             13     3.6
# 3        1.0  ...         Coconut Butter       19             13     8.4
# 4        0.0  ...      Natural Sweetener       17             13    13.7
#
#      price_range_loc     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy  Regularly busy        Average orders
# 2  Low-range product  Regularly busy  Regularly busy        Average orders
# 3  Mid-range product  Regularly busy  Regularly busy        Average orders
# 4  Mid-range product  Regularly busy  Regularly busy        Average orders
#
#   max_order  loyalty_flag
# 0       8.0  New customer
# 1       8.0  New customer
# 2       8.0  New customer
# 3       8.0  New customer
# 4       8.0  New customer
#
# [5 rows x 21 columns]

# %%
# Check shape 
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# If statements with the loc () function
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Print frequency 
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# NaN                  2076096
# Name: count, dtype: int64

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# Identify specific columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(15)
# Out:
#      user_id      loyalty_flag  order_number
# 0   202279.0      New customer           3.0
# 1   202279.0      New customer           3.0
# 2   202279.0      New customer           3.0
# 3   202279.0      New customer           3.0
# 4   202279.0      New customer           3.0
# 5   202279.0      New customer           3.0
# 6   202279.0      New customer           3.0
# 7   202279.0      New customer           3.0
# 8   202279.0      New customer           3.0
# 9   205970.0  Regular customer          16.0
# 10  205970.0  Regular customer          16.0
# 11  205970.0  Regular customer          16.0
# 12  205970.0  Regular customer          16.0
# 13  205970.0  Regular customer          16.0
# 14  205970.0  Regular customer          16.0

# %% [markdown]
# #### 05. Check Statistics

# %%
# Group by loyalty_flag and describe prices
ords_prods_merge.groupby('loyalty_flag')['prices'].describe()
# Out:
#                        count      mean       std  min  25%  50%   75%   max
# loyalty_flag
# Loyal customer    10094068.0  7.774068  4.206601  1.0  4.2  7.4  11.2  25.0
# New customer       5150733.0  7.802315  4.267897  1.0  4.2  7.4  11.3  25.0
# Regular customer  15079186.0  7.799374  4.255452  1.0  4.2  7.4  11.3  25.0

# %% [markdown]
# #### 06. Create a Spending Flag

# %%
# Split the data into groups based on the “user_id” column.
# Apply the transform() function on the “prices” column to generate the average price per user. 
# Create a new column, “avg_spending,” into which you’ll place the results of your aggregation.
ords_prods_merge['avg_spending'] = ords_prods_merge.groupby('user_id')['prices'].transform('mean')

# %%
# Check output
ords_prods_merge.head()
# Out:
#    order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0         2  202279.0         prior           3.0                 5.0
# 1         2  202279.0         prior           3.0                 5.0
# 2         2  202279.0         prior           3.0                 5.0
# 3         2  202279.0         prior           3.0                 5.0
# 4         2  202279.0         prior           3.0                 5.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                9.0                     8.0     33120.0                1.0
# 1                9.0                     8.0     28985.0                2.0
# 2                9.0                     8.0      9327.0                3.0
# 3                9.0                     8.0     45918.0                4.0
# 4                9.0                     8.0     30035.0                5.0
#
#    reordered  ... aisle_id department_id  prices    price_range_loc  \
# 0        1.0  ...       86            16    11.3  Mid-range product
# 1        1.0  ...       83             4    13.4  Mid-range product
# 2        0.0  ...      104            13     3.6  Low-range product
# 3        1.0  ...       19            13     8.4  Mid-range product
# 4        0.0  ...       17            13    13.7  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy        Average orders       8.0
# 1  Regularly busy  Regularly busy        Average orders       8.0
# 2  Regularly busy  Regularly busy        Average orders       8.0
# 3  Regularly busy  Regularly busy        Average orders       8.0
# 4  Regularly busy  Regularly busy        Average orders       8.0
#
#    loyalty_flag  avg_spending
# 0  New customer        8.6875
# 1  New customer        8.6875
# 2  New customer        8.6875
# 3  New customer        8.6875
# 4  New customer        8.6875
#
# [5 rows x 22 columns]

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 22)

# %%
# If statements with the loc () function
ords_prods_merge.loc[ords_prods_merge['avg_spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
# If statements with the loc () function
ords_prods_merge.loc[ords_prods_merge['avg_spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Print frequency 
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     30207666
# NaN              2076096
# High spender      121097
# Name: count, dtype: int64

# %%
# Check output
ords_prods_merge.head()
# Out:
#    order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0         2  202279.0         prior           3.0                 5.0
# 1         2  202279.0         prior           3.0                 5.0
# 2         2  202279.0         prior           3.0                 5.0
# 3         2  202279.0         prior           3.0                 5.0
# 4         2  202279.0         prior           3.0                 5.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                9.0                     8.0     33120.0                1.0
# 1                9.0                     8.0     28985.0                2.0
# 2                9.0                     8.0      9327.0                3.0
# 3                9.0                     8.0     45918.0                4.0
# 4                9.0                     8.0     30035.0                5.0
#
#    reordered  ... department_id prices    price_range_loc     busiest_day  \
# 0        1.0  ...            16   11.3  Mid-range product  Regularly busy
# 1        1.0  ...             4   13.4  Mid-range product  Regularly busy
# 2        0.0  ...            13    3.6  Low-range product  Regularly busy
# 3        1.0  ...            13    8.4  Mid-range product  Regularly busy
# 4        0.0  ...            13   13.7  Mid-range product  Regularly busy
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag avg_spending  \
# 0  Regularly busy        Average orders       8.0  New customer       8.6875
# 1  Regularly busy        Average orders       8.0  New customer       8.6875
# 2  Regularly busy        Average orders       8.0  New customer       8.6875
# 3  Regularly busy        Average orders       8.0  New customer       8.6875
# 4  Regularly busy        Average orders       8.0  New customer       8.6875
#
#    spending_flag
# 0    Low spender
# 1    Low spender
# 2    Low spender
# 3    Low spender
# 4    Low spender
#
# [5 rows x 23 columns]

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 23)

# %% [markdown]
# #### 07. Create a Frequency Flag

# %%
# Split the data into groups based on the “user_id” column.
# Apply the transform() function on the “days_since_prior_order” column to generate the median order per user. 
# Create a new column, “median_order,” into which you’ll place the results of your aggregation.
ords_prods_merge['median_order'] = ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform('median')

# %%
# Check output
ords_prods_merge.head()
# Out:
#    order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0         2  202279.0         prior           3.0                 5.0
# 1         2  202279.0         prior           3.0                 5.0
# 2         2  202279.0         prior           3.0                 5.0
# 3         2  202279.0         prior           3.0                 5.0
# 4         2  202279.0         prior           3.0                 5.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                9.0                     8.0     33120.0                1.0
# 1                9.0                     8.0     28985.0                2.0
# 2                9.0                     8.0      9327.0                3.0
# 3                9.0                     8.0     45918.0                4.0
# 4                9.0                     8.0     30035.0                5.0
#
#    reordered  ... prices    price_range_loc     busiest_day    busiest_days  \
# 0        1.0  ...   11.3  Mid-range product  Regularly busy  Regularly busy
# 1        1.0  ...   13.4  Mid-range product  Regularly busy  Regularly busy
# 2        0.0  ...    3.6  Low-range product  Regularly busy  Regularly busy
# 3        1.0  ...    8.4  Mid-range product  Regularly busy  Regularly busy
# 4        0.0  ...   13.7  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day max_order  loyalty_flag avg_spending spending_flag  \
# 0         Average orders       8.0  New customer       8.6875   Low spender
# 1         Average orders       8.0  New customer       8.6875   Low spender
# 2         Average orders       8.0  New customer       8.6875   Low spender
# 3         Average orders       8.0  New customer       8.6875   Low spender
# 4         Average orders       8.0  New customer       8.6875   Low spender
#
#    median_order
# 0          24.0
# 1          24.0
# 2          24.0
# 3          24.0
# 4          24.0
#
# [5 rows x 24 columns]

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
# If statements with the loc () function
ords_prods_merge.loc[ords_prods_merge['median_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_order'] > 10) & (ords_prods_merge['median_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Print frequency 
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# NaN                       2076096
# Name: count, dtype: int64

# %%
# Check output
ords_prods_merge.head()
# Out:
#    order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0         2  202279.0         prior           3.0                 5.0
# 1         2  202279.0         prior           3.0                 5.0
# 2         2  202279.0         prior           3.0                 5.0
# 3         2  202279.0         prior           3.0                 5.0
# 4         2  202279.0         prior           3.0                 5.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                9.0                     8.0     33120.0                1.0
# 1                9.0                     8.0     28985.0                2.0
# 2                9.0                     8.0      9327.0                3.0
# 3                9.0                     8.0     45918.0                4.0
# 4                9.0                     8.0     30035.0                5.0
#
#    reordered  ...    price_range_loc     busiest_day    busiest_days  \
# 0        1.0  ...  Mid-range product  Regularly busy  Regularly busy
# 1        1.0  ...  Mid-range product  Regularly busy  Regularly busy
# 2        0.0  ...  Low-range product  Regularly busy  Regularly busy
# 3        1.0  ...  Mid-range product  Regularly busy  Regularly busy
# 4        0.0  ...  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day  max_order  loyalty_flag avg_spending spending_flag  \
# 0         Average orders        8.0  New customer       8.6875   Low spender
# 1         Average orders        8.0  New customer       8.6875   Low spender
# 2         Average orders        8.0  New customer       8.6875   Low spender
# 3         Average orders        8.0  New customer       8.6875   Low spender
# 4         Average orders        8.0  New customer       8.6875   Low spender
#
#   median_order   order_frequency_flag
# 0         24.0  Non-frequent customer
# 1         24.0  Non-frequent customer
# 2         24.0  Non-frequent customer
# 3         24.0  Non-frequent customer
# 4         24.0  Non-frequent customer
#
# [5 rows x 25 columns]

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 25)

# %% [markdown]
# #### 08. Export Dataframe

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02_Data','Prepared Data', 'ords_prods_merge_grouped.pkl'))
