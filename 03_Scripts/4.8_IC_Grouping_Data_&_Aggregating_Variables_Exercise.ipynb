# %% [markdown]
# # 4.8 IC Grouping Data & Aggregating Variables Exercise

# %% [markdown]
# ## Contents:

# %% [markdown]
# ### 01. Imporitng Libraries

# %% [markdown]
# ### 02. Create a Subset

# %% [markdown]
# ### 03. Grouping Data with pandas

# %% [markdown]
# ### 04. Aggregating Data with agg()

# %% [markdown]
# ### 05. Aggregating Data with transform()

# %% [markdown]
# ### 06. Deriving Columns with loc()

# %% [markdown]
# ### 07. Exporitng dataframe

# %% [markdown]
# #### 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing df_ords_prods_merge
path = r'/Users/yaseminmustafa/Desktop/CareerFoundry/Exercise 4/15-05-2025_Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path,"02_Data/Prepared Data/ords_prods_merge_new_variables.pkl"))

# %%
# Check output
ords_prods_merge.head()
# Out:
#    order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0         2  202279.0         prior           3.0                 5.0
# 1         2  202279.0         prior           3.0                 5.0
# 2         2  202279.0         prior           3.0                 5.0
# 3         2  202279.0         prior           3.0                 5.0
# 4         2  202279.0         prior           3.0                 5.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                9.0                     8.0     33120.0                1.0
# 1                9.0                     8.0     28985.0                2.0
# 2                9.0                     8.0      9327.0                3.0
# 3                9.0                     8.0     45918.0                4.0
# 4                9.0                     8.0     30035.0                5.0
#
#    reordered _merge           product_name  aisle_id  department_id  prices  \
# ...

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# #### 02. Create a Subset

# %%
# Create subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %% [markdown]
# #### 03. Grouping Data with pandas

# %%
# Split data into group product_name in df
df.groupby('product_name')

# %% [markdown]
# #### 04. Aggregating Data with agg()

# %%
# Split the data into groups based on department_id and apply the agg() function to obtain mean values for the order_number column
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.731090
# 2                19.586011
# 3                18.556774
# 4                19.080298
# 5                15.707791
# 6                17.682115
# 7                18.521677
# 8                17.102641
# 9                17.233564
# 10               22.162369
# 11               17.686431
# 12               17.225351
# 13               17.965434
# 14               18.044586
# 15               17.581762
# 16               18.925072
# 17               17.140737
# 18               20.112791
# 19               18.511760
# 20               17.796863
# 21               24.022115

# %%
# Split the data into groups based on department_id and apply the mean() function to obtain mean values for the order_number column
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     16.731090
# 2     19.586011
# 3     18.556774
# 4     19.080298
# 5     15.707791
# 6     17.682115
# 7     18.521677
# 8     17.102641
# 9     17.233564
# 10    22.162369
# 11    17.686431
# 12    17.225351
# 13    17.965434
# 14    18.044586
# 15    17.581762
# 16    18.925072
# 17    17.140737
# 18    20.112791
# 19    18.511760
# 20    17.796863
# 21    24.022115
# Name: order_number, dtype: float64

# %%
# Split the data into groups based on department_id and apply the mean() function to obtain mean values for the order_number column
# Can alternatively be written as
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     16.731090
# 2     19.586011
# 3     18.556774
# 4     19.080298
# 5     15.707791
# 6     17.682115
# 7     18.521677
# 8     17.102641
# 9     17.233564
# 10    22.162369
# 11    17.686431
# 12    17.225351
# 13    17.965434
# 14    18.044586
# 15    17.581762
# 16    18.925072
# 17    17.140737
# 18    20.112791
# 19    18.511760
# 20    17.796863
# 21    24.022115
# Name: order_number, dtype: float64

# %%
# Split the data into groups based on department_id and apply the mean(), min(), and max() function 
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 1                16.731090  2.0  99.0
# 2                19.586011  2.0  97.0
# 3                18.556774  2.0  99.0
# 4                19.080298  2.0  99.0
# 5                15.707791  2.0  99.0
# 6                17.682115  2.0  99.0
# 7                18.521677  2.0  99.0
# 8                17.102641  2.0  96.0
# 9                17.233564  2.0  99.0
# 10               22.162369  2.0  99.0
# 11               17.686431  2.0  99.0
# 12               17.225351  2.0  99.0
# 13               17.965434  2.0  99.0
# 14               18.044586  2.0  99.0
# 15               17.581762  2.0  99.0
# 16               18.925072  2.0  99.0
# 17               17.140737  2.0  99.0
# 18               20.112791  2.0  99.0
# 19               18.511760  2.0  99.0
# 20               17.796863  2.0  99.0
# 21               24.022115  2.0  98.0

# %% [markdown]
# #### 05. Aggregating Data with transform()

# %%
# Split the data into groups based on the “user_id” column.
# Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# Create a new column, “max_order,” into which you’ll place the results of your aggregation.
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/nr/1brwh_xs1n5_2h6494zpg7jm0000gn/T/ipykernel_7011/1765782716.py:4: FutureWarning: The provided callable <function max at 0x10c4b0900> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check output
ords_prods_merge.head(15)
# Out:
#     order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0          2  202279.0         prior           3.0                 5.0
# 1          2  202279.0         prior           3.0                 5.0
# 2          2  202279.0         prior           3.0                 5.0
# 3          2  202279.0         prior           3.0                 5.0
# 4          2  202279.0         prior           3.0                 5.0
# 5          2  202279.0         prior           3.0                 5.0
# 6          2  202279.0         prior           3.0                 5.0
# 7          2  202279.0         prior           3.0                 5.0
# 8          2  202279.0         prior           3.0                 5.0
# 9          3  205970.0         prior          16.0                 5.0
# 10         3  205970.0         prior          16.0                 5.0
# 11         3  205970.0         prior          16.0                 5.0
# ...

# %% [markdown]
# ##### My user_id and order_id column appear to be reversed compared to the exercise example.
# ##### Also, the numbers in the “order_number” don't match the values in the “max_order” column.

# %%
# Check output
ords_prods_merge.head(100)
# Out:
#     order_id   user_id dataset_label  order_number  orders_day_of_week  \
# 0          2  202279.0         prior           3.0                 5.0
# 1          2  202279.0         prior           3.0                 5.0
# 2          2  202279.0         prior           3.0                 5.0
# 3          2  202279.0         prior           3.0                 5.0
# 4          2  202279.0         prior           3.0                 5.0
# ..       ...       ...           ...           ...                 ...
# 95        11  143742.0         prior           4.0                 1.0
# 96        11  143742.0         prior           4.0                 1.0
# 97        12  152610.0         prior          22.0                 6.0
# 98        12  152610.0         prior          22.0                 6.0
# 99        12  152610.0         prior          22.0                 6.0
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# ...

# %%
# Overiding Jupyter's display option
pd.options.display.max_rows = None

# %% [markdown]
# #### 06. Deriving Columns with loc()

# %%
# If statements with the loc () function
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Print frequency 
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# NaN                  2076096
# Name: count, dtype: int64

# %%
# Check shape
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# Identify specific columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#      user_id      loyalty_flag  order_number
# 0   202279.0      New customer           3.0
# 1   202279.0      New customer           3.0
# 2   202279.0      New customer           3.0
# 3   202279.0      New customer           3.0
# 4   202279.0      New customer           3.0
# 5   202279.0      New customer           3.0
# 6   202279.0      New customer           3.0
# 7   202279.0      New customer           3.0
# 8   202279.0      New customer           3.0
# 9   205970.0  Regular customer          16.0
# 10  205970.0  Regular customer          16.0
# 11  205970.0  Regular customer          16.0
# 12  205970.0  Regular customer          16.0
# 13  205970.0  Regular customer          16.0
# 14  205970.0  Regular customer          16.0
# 15  205970.0  Regular customer          16.0
# 16  205970.0  Regular customer          16.0
# 17  178520.0    Loyal customer          36.0
# 18  178520.0    Loyal customer          36.0
# 19  178520.0    Loyal customer          36.0
# ...

# %% [markdown]
# #### 07. Exporitng Dataframe

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02_Data','Prepared Data', 'ords_prods_merge_aggregated.pkl'))
